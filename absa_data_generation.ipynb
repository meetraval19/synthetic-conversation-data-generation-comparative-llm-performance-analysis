# %%
import os
import random
import json
from openai import OpenAI

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# We are saving each conversation in a text file so that we can restart the processed from the last processed data point
fields = ["Technology", "Healthcare", "Finance", "legal"]

# Since there are 20 topics, we will create 20 folders where for each folder, 
# we are keeping on topic fixed and randomly selecting the remaining topics
for field in fields:
  field_path = f"/content/drive/MyDrive/{add_your_path_here}/{field}/Conversation_Data"
  for i in range(0, 20,1):
    folder_path = f"{field_path}/{i}"
    print(folder_path)
    if not os.path.exists(folder_path):
      os.makedirs(folder_path)

# %%
# Below code is for only 1 field
# If you have multiple fields of interest, you need to run it multiple times

# %%
field = "add-field-here"
type_of_conversations =  [],  # Your Choice your fields
topics = [] # your choice of topics

sentiments = ['positive', 'negative', 'neutral']

# We want to generate 3000 conversation
# Since we have 20 topics, we decided to keep 1 topic fixed for 3000/20 = 150 times 
first_topic_fixed_conversation_count = 150  

# Proportion of positive, negative and netural sentiments we want for the fixed topic
positive_proportion = 0.4
negative_proportion = 0.4
neutral_proportion = 0.2

# %%
class DataGenerator:

  # Constructor method to initialize the car object
  def __init__(
              self,
               field,
               type_of_conversations,
               topics, sentiments,
               first_topic_fixed_conversation_count,
               positive_proportion,
               negative_proportion,
               model_type,
               model_name = "gpt-4o"
               ):

      self.field = field
      self.type_of_conversations = type_of_conversations
      self.topics = topics
      self.sentiments = sentiments
      self.first_topic_fixed_conversation_count = first_topic_fixed_conversation_count
      self.total_conversation_count = self.first_topic_fixed_conversation_count * len(self.topics)
      self.positive_proportion = positive_proportion
      self.negative_proportion = negative_proportion
      self.model_type = model_type
      self.model_name = model_name

      self.client = OpenAI(
                    api_key="add-api-key"
      )


  def getSentiment(self, iter_count):
    if iter_count < self.first_topic_fixed_conversation_count * self.positive_proportion:
        sentiment = 'positive'
    elif iter_count < self.first_topic_fixed_conversation_count * (self.positive_proportion + self.negative_proportion):
        sentiment = 'negative'
    else:
        sentiment = 'neutral'
    return sentiment

  def generatePrompt(self, type_of_conversation, topic_sentiment_dictionary):

    return f"""You are tasked with generating a dialogue-based conversation with about 400 words based on the following input parameters:
    1. Field: <Field>
    2. Type of Conversation: <Type of Conversation>
    3. Topics and Sentiments: <Dictionary containing the topics and their corresponding sentiments. For example: {{"Topic1": "positive", "Topic2": "negative", "Topic3": "neutral"}}>


    **Instructions**:
    - Create a dialogue-based conversation that is specific to the field mentioned.
    - Ensure the conversation involves all the topics provided in the Topics and Sentiments dictionary.
    - Avoid using the topic names directly in the conversation.
    - Prefer mentioning about sub-topics related to the selected main topic
    - Annotate each speaker in the conversation simply by labeling them as "Speaker A", "Speaker B", etc.
    - Use the Topics and Sentiments dictionary to add a sentimental aspect around each topic, and apply the corresponding sentiment from the dictionary for each topic.
    - The conversation should reflect realistic exchanges, with each character responding naturally to the topics.
    - The sentiment for each topic must be directly reflected in the conversation, based on the Topics and Sentiments dictionary values.
    - Each topic mentioned in the Topics and Sentiments must be addressed in the dialogue, and each speaker's sentiment should align with the assigned sentiment for that topic.


    **Output Format**:
    Provide the conversation like this:


    "<Deepseek generated conversation>"




    ### Example:


    If the field is "Technology", and the conversation type is "technical", with the topics and sentiments dictionary as:
    {{"AI Development": "positive", "Data Security": "negative", "Software Bugs": "neutral"}}


    The output should look like:


    "Speaker A: 'AI development has made huge strides in the last few years.' Speaker B: 'True, but we must also be cautious about data security risks with AI.' Speaker A: 'Yes, but AI can also improve data security.' Speaker B: 'True, but there's always the risk of software bugs making everything more complex.'"


    Now your turn!
    1. Field: {self.field}
    2. Type of Conversation: {type_of_conversation}
    3. Topics and Sentiments: {topic_sentiment_dictionary}


    Output:
    """;

  def generateLLMResponse(self, prompt):
    response = self.client.responses.create(
        model=self.model_name,
        input=prompt
    )
    return response.output_text

# %%
def getFilePath(topic_index, fixed_topic_first_selection_count, topic_sentiment_dictionary):
    filename = f"conversation_{fixed_topic_first_selection_count}"
    for key, value in topic_sentiment_dictionary.items():
        index = topics.index(key)
        filename += f"_{index}_{value}"
    return f"/content/drive/MyDrive/Sentiment_Analysis/{field}/Conversation_Data/{topic_index}/{filename}.txt"


def getResponse(inputModel, prompt, topic_index, fixed_topic_first_selection_count,  topic_sentiment_dictionary):
  retry_count = 0
  while retry_count < 5:
    try:
      llm_response = inputModel.generateLLMResponse(prompt)
      filename = getFilePath(topic_index, fixed_topic_first_selection_count, topic_sentiment_dictionary)
      with open(filename, 'w') as file:
        file.write(llm_response)
      print(f"Saved to {filename} for topic {inputModel.topics[topic_index]} with count as {fixed_topic_first_selection_count}]")
      break
    except Exception as e:
      retry_count+=1
      if(retry_count == 5):
        raise e

  return llm_response

# %%
def generateData(inputModel, iter_start_count = 0, iter_end_count = 0, per_topic_addition = 0):
    print(inputModel.model_name)
    index = iter_start_count
    max_iterations = iter_end_count

    if max_iterations == 0:
      max_iterations = inputModel.total_conversation_count

    while( index < max_iterations):

      # Index of the topic we will use
      topic_index = index // inputModel.first_topic_fixed_conversation_count

      # Number of times this topic has been selected as first topic
      fixed_topic_first_selection_count = index % inputModel.first_topic_fixed_conversation_count

      # Topic Name
      fixed_topic = inputModel.topics[topic_index]

      # Type of converstaion
      type_of_conversation = random.choice(inputModel.type_of_conversations)


      # Assign a sentiment to the topic
      topic_sentiment_dictionary = {}


      # Get sentiment based on the number of times this element is selected as first topic
      topic_sentiment = inputModel.getSentiment(fixed_topic_first_selection_count)
      topic_sentiment_dictionary[fixed_topic] = topic_sentiment


      # Get Topic pool to select remaining topics
      topics_pool = [t for t in inputModel.topics if t != fixed_topic]

      # Randomly select additional topics
      extra_topics = random.sample(topics_pool, random.randint(1, 2))

      # Get Sentiment pool to select sentiment for remaining topics
      sentiments_pool = [s for s in inputModel.sentiments if s != topic_sentiment]


      # Assign different sentiments to these topics
      for extra_topic in extra_topics:
        extra_topic_sentiment = random.choice(sentiments_pool)
        topic_sentiment_dictionary[extra_topic] = extra_topic_sentiment



      prompt = inputModel.generatePrompt(type_of_conversation, topic_sentiment_dictionary)

      try:
        llm_response = getResponse(inputModel, prompt, topic_index, fixed_topic_first_selection_count, topic_sentiment_dictionary)
      except Exception as e:
        print(f"Found error while running for main iteration count: {index}")
        print(e)
        return

      print(f"Number of conversations completed: {index}")

      index+=1

# %%
model = DataGenerator(
    field,
    type_of_conversations,
    topics, sentiments,
    first_topic_fixed_conversation_count,
    positive_proportion,
    negative_proportion,
    "openAI",
    'gpt-4o'
    )

# %%
generateData2(model, 0 , 3000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_50_3_positive_7_neutral_19_negative.txt for topic Creditworthiness Evaluation with count as 50]
# Number of conversations completed: 500
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_51_3_positive_6_negative_5_negative.txt for topic Creditworthiness Evaluation with count as 51]
# Number of conversations completed: 501
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_52_3_positive_7_negative_12_negative.txt for topic Creditworthiness Evaluation with count as 52]
# Number of conversations completed: 502
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_53_3_positive_2_neutral.txt for topic Creditworthiness Evaluation with count as 53]
# Number of conversations completed: 503
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_54_3_positive_12_negative.txt for topic Creditworthiness Evaluation with count as 54]
# Number of conversations completed: 504
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_55_3_positive_17_negative_9_negative.txt for topic Creditworthiness Evaluation with count as 55]
# Number of conversations completed: 505
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_56_3_positive_16_neutral.txt for topic Creditworthiness Evaluation with count as 56]
# Number of conversations completed: 506
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_57_3_positive_13_negative_6_neutral.txt for topic Creditworthiness Evaluation with count as 57]
# Number of conversations completed: 507
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_58_3_positive_14_negative.txt for topic Creditworthiness Evaluation with count as 58]
# Number of conversations completed: 508
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_59_3_positive_1_negative_6_negative.txt for topic Creditworthiness Evaluation with count as 59]
# Number of conversations completed: 509
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_60_3_negative_1_neutral.txt for topic Creditworthiness Evaluation with count as 60]
# Number of conversations completed: 510
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_61_3_negative_12_positive_15_positive.txt for topic Creditworthiness Evaluation with count as 61]
# Number of conversations completed: 511
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_62_3_negative_18_positive.txt for topic Creditworthiness Evaluation with count as 62]
# Number of conversations completed: 512
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_63_3_negative_14_positive.txt for topic Creditworthiness Evaluation with count as 63]
# Number of conversations completed: 513
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_64_3_negative_19_neutral.txt for topic Creditworthiness Evaluation with count as 64]
# Number of conversations completed: 514
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_65_3_negative_2_neutral_11_positive.txt for topic Creditworthiness Evaluation with count as 65]
# Number of conversations completed: 515
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_66_3_negative_15_neutral.txt for topic Creditworthiness Evaluation with count as 66]
# Number of conversations completed: 516
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_67_3_negative_18_neutral_16_positive.txt for topic Creditworthiness Evaluation with count as 67]
# Number of conversations completed: 517
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_68_3_negative_14_neutral.txt for topic Creditworthiness Evaluation with count as 68]
# Number of conversations completed: 518
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_69_3_negative_2_positive.txt for topic Creditworthiness Evaluation with count as 69]
# Number of conversations completed: 519
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_70_3_negative_11_positive_8_neutral.txt for topic Creditworthiness Evaluation with count as 70]
# Number of conversations completed: 520
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_71_3_negative_19_neutral.txt for topic Creditworthiness Evaluation with count as 71]
# Number of conversations completed: 521
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_72_3_negative_19_neutral_13_neutral.txt for topic Creditworthiness Evaluation with count as 72]
# Number of conversations completed: 522
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_73_3_negative_19_neutral_5_positive.txt for topic Creditworthiness Evaluation with count as 73]
# Number of conversations completed: 523
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_74_3_negative_13_neutral.txt for topic Creditworthiness Evaluation with count as 74]
# Number of conversations completed: 524
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_75_3_negative_15_positive_1_positive.txt for topic Creditworthiness Evaluation with count as 75]
# Number of conversations completed: 525
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_76_3_negative_13_positive.txt for topic Creditworthiness Evaluation with count as 76]
# Number of conversations completed: 526
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_77_3_negative_8_positive.txt for topic Creditworthiness Evaluation with count as 77]
# Number of conversations completed: 527
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_78_3_negative_14_neutral.txt for topic Creditworthiness Evaluation with count as 78]
# Number of conversations completed: 528
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_79_3_negative_0_positive_19_positive.txt for topic Creditworthiness Evaluation with count as 79]
# Number of conversations completed: 529
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_80_3_negative_5_neutral_9_positive.txt for topic Creditworthiness Evaluation with count as 80]
# Number of conversations completed: 530
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_81_3_negative_12_neutral_5_neutral.txt for topic Creditworthiness Evaluation with count as 81]
# Number of conversations completed: 531
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_82_3_negative_19_positive.txt for topic Creditworthiness Evaluation with count as 82]
# Number of conversations completed: 532
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_83_3_negative_4_positive.txt for topic Creditworthiness Evaluation with count as 83]
# Number of conversations completed: 533
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_84_3_negative_2_positive_9_neutral.txt for topic Creditworthiness Evaluation with count as 84]
# Number of conversations completed: 534
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_85_3_negative_5_neutral_10_neutral.txt for topic Creditworthiness Evaluation with count as 85]
# Number of conversations completed: 535
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_86_3_negative_18_positive.txt for topic Creditworthiness Evaluation with count as 86]
# Number of conversations completed: 536
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_87_3_negative_0_positive.txt for topic Creditworthiness Evaluation with count as 87]
# Number of conversations completed: 537
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_88_3_negative_9_neutral.txt for topic Creditworthiness Evaluation with count as 88]
# Number of conversations completed: 538
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_89_3_negative_8_positive_0_positive.txt for topic Creditworthiness Evaluation with count as 89]
# Number of conversations completed: 539
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_90_3_negative_17_positive_4_positive.txt for topic Creditworthiness Evaluation with count as 90]
# Number of conversations completed: 540
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_91_3_negative_18_positive.txt for topic Creditworthiness Evaluation with count as 91]
# Number of conversations completed: 541
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_92_3_negative_9_neutral_19_positive.txt for topic Creditworthiness Evaluation with count as 92]
# Number of conversations completed: 542
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_93_3_negative_11_neutral.txt for topic Creditworthiness Evaluation with count as 93]
# Number of conversations completed: 543
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_94_3_negative_1_positive.txt for topic Creditworthiness Evaluation with count as 94]
# Number of conversations completed: 544
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_95_3_negative_16_neutral_17_positive.txt for topic Creditworthiness Evaluation with count as 95]
# Number of conversations completed: 545
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_96_3_negative_15_positive.txt for topic Creditworthiness Evaluation with count as 96]
# Number of conversations completed: 546
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_97_3_negative_0_neutral_18_neutral.txt for topic Creditworthiness Evaluation with count as 97]
# Number of conversations completed: 547
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_98_3_negative_13_neutral.txt for topic Creditworthiness Evaluation with count as 98]
# Number of conversations completed: 548
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_99_3_negative_14_neutral_9_neutral.txt for topic Creditworthiness Evaluation with count as 99]
# Number of conversations completed: 549
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_100_3_negative_4_neutral.txt for topic Creditworthiness Evaluation with count as 100]
# Number of conversations completed: 550
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_101_3_negative_10_neutral_16_neutral.txt for topic Creditworthiness Evaluation with count as 101]
# Number of conversations completed: 551
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_102_3_negative_16_neutral_11_positive.txt for topic Creditworthiness Evaluation with count as 102]
# Number of conversations completed: 552
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_103_3_negative_2_neutral.txt for topic Creditworthiness Evaluation with count as 103]
# Number of conversations completed: 553
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_104_3_negative_4_positive.txt for topic Creditworthiness Evaluation with count as 104]
# Number of conversations completed: 554
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_105_3_negative_9_positive.txt for topic Creditworthiness Evaluation with count as 105]
# Number of conversations completed: 555
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_106_3_negative_17_neutral.txt for topic Creditworthiness Evaluation with count as 106]
# Number of conversations completed: 556
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_107_3_negative_9_positive.txt for topic Creditworthiness Evaluation with count as 107]
# Number of conversations completed: 557
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_108_3_negative_10_positive_1_positive.txt for topic Creditworthiness Evaluation with count as 108]
# Number of conversations completed: 558
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_109_3_negative_9_neutral_16_positive.txt for topic Creditworthiness Evaluation with count as 109]
# Number of conversations completed: 559
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_110_3_negative_2_neutral_9_positive.txt for topic Creditworthiness Evaluation with count as 110]
# Number of conversations completed: 560
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_111_3_negative_4_positive_13_neutral.txt for topic Creditworthiness Evaluation with count as 111]
# Number of conversations completed: 561
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_112_3_negative_19_neutral_0_positive.txt for topic Creditworthiness Evaluation with count as 112]
# Number of conversations completed: 562
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_113_3_negative_14_neutral_17_neutral.txt for topic Creditworthiness Evaluation with count as 113]
# Number of conversations completed: 563
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_114_3_negative_18_neutral_14_neutral.txt for topic Creditworthiness Evaluation with count as 114]
# Number of conversations completed: 564
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_115_3_negative_4_positive_9_neutral.txt for topic Creditworthiness Evaluation with count as 115]
# Number of conversations completed: 565
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_116_3_negative_10_neutral.txt for topic Creditworthiness Evaluation with count as 116]
# Number of conversations completed: 566
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_117_3_negative_1_positive_10_positive.txt for topic Creditworthiness Evaluation with count as 117]
# Number of conversations completed: 567
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_118_3_negative_16_positive.txt for topic Creditworthiness Evaluation with count as 118]
# Number of conversations completed: 568
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_119_3_negative_0_neutral_18_positive.txt for topic Creditworthiness Evaluation with count as 119]
# Number of conversations completed: 569
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_120_3_neutral_10_positive.txt for topic Creditworthiness Evaluation with count as 120]
# Number of conversations completed: 570
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_121_3_neutral_17_negative.txt for topic Creditworthiness Evaluation with count as 121]
# Number of conversations completed: 571
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_122_3_neutral_9_negative_6_negative.txt for topic Creditworthiness Evaluation with count as 122]
# Number of conversations completed: 572
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_123_3_neutral_6_positive_7_positive.txt for topic Creditworthiness Evaluation with count as 123]
# Number of conversations completed: 573
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_124_3_neutral_2_positive.txt for topic Creditworthiness Evaluation with count as 124]
# Number of conversations completed: 574
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_125_3_neutral_11_negative.txt for topic Creditworthiness Evaluation with count as 125]
# Number of conversations completed: 575
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_126_3_neutral_12_negative.txt for topic Creditworthiness Evaluation with count as 126]
# Number of conversations completed: 576
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_127_3_neutral_16_negative.txt for topic Creditworthiness Evaluation with count as 127]
# Number of conversations completed: 577
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_128_3_neutral_6_negative.txt for topic Creditworthiness Evaluation with count as 128]
# Number of conversations completed: 578
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_129_3_neutral_12_positive_19_positive.txt for topic Creditworthiness Evaluation with count as 129]
# Number of conversations completed: 579
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_130_3_neutral_19_negative.txt for topic Creditworthiness Evaluation with count as 130]
# Number of conversations completed: 580
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_131_3_neutral_12_negative_2_positive.txt for topic Creditworthiness Evaluation with count as 131]
# Number of conversations completed: 581
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_132_3_neutral_12_positive_1_positive.txt for topic Creditworthiness Evaluation with count as 132]
# Number of conversations completed: 582
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_133_3_neutral_13_negative_4_negative.txt for topic Creditworthiness Evaluation with count as 133]
# Number of conversations completed: 583
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_134_3_neutral_0_negative.txt for topic Creditworthiness Evaluation with count as 134]
# Number of conversations completed: 584
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_135_3_neutral_4_negative_11_positive.txt for topic Creditworthiness Evaluation with count as 135]
# Number of conversations completed: 585
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_136_3_neutral_16_negative_10_positive.txt for topic Creditworthiness Evaluation with count as 136]
# Number of conversations completed: 586
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_137_3_neutral_10_negative.txt for topic Creditworthiness Evaluation with count as 137]
# Number of conversations completed: 587
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_138_3_neutral_18_positive_4_negative.txt for topic Creditworthiness Evaluation with count as 138]
# Number of conversations completed: 588
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_139_3_neutral_8_negative.txt for topic Creditworthiness Evaluation with count as 139]
# Number of conversations completed: 589
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_140_3_neutral_17_negative_16_positive.txt for topic Creditworthiness Evaluation with count as 140]
# Number of conversations completed: 590
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_141_3_neutral_4_negative_16_negative.txt for topic Creditworthiness Evaluation with count as 141]
# Number of conversations completed: 591
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_142_3_neutral_0_positive_5_negative.txt for topic Creditworthiness Evaluation with count as 142]
# Number of conversations completed: 592
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_143_3_neutral_10_positive.txt for topic Creditworthiness Evaluation with count as 143]
# Number of conversations completed: 593
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_144_3_neutral_11_negative_15_negative.txt for topic Creditworthiness Evaluation with count as 144]
# Number of conversations completed: 594
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_145_3_neutral_17_positive.txt for topic Creditworthiness Evaluation with count as 145]
# Number of conversations completed: 595
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_146_3_neutral_5_negative_4_positive.txt for topic Creditworthiness Evaluation with count as 146]
# Number of conversations completed: 596
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_147_3_neutral_8_negative_15_negative.txt for topic Creditworthiness Evaluation with count as 147]
# Number of conversations completed: 597
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_148_3_neutral_2_negative.txt for topic Creditworthiness Evaluation with count as 148]
# Number of conversations completed: 598
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/3/conversation_149_3_neutral_12_positive_2_positive.txt for topic Creditworthiness Evaluation with count as 149]
# Number of conversations completed: 599
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_0_4_positive_5_neutral.txt for topic Investment Performance Review with count as 0]
# Number of conversations completed: 600
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_1_4_positive_13_negative.txt for topic Investment Performance Review with count as 1]
# Number of conversations completed: 601
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_2_4_positive_8_neutral.txt for topic Investment Performance Review with count as 2]
# Number of conversations completed: 602
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_3_4_positive_0_neutral_17_negative.txt for topic Investment Performance Review with count as 3]
# Number of conversations completed: 603
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_4_4_positive_7_negative.txt for topic Investment Performance Review with count as 4]
# Number of conversations completed: 604
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_5_4_positive_17_neutral.txt for topic Investment Performance Review with count as 5]
# Number of conversations completed: 605
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_6_4_positive_6_neutral.txt for topic Investment Performance Review with count as 6]
# Number of conversations completed: 606
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_7_4_positive_16_neutral.txt for topic Investment Performance Review with count as 7]
# Number of conversations completed: 607
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_8_4_positive_3_neutral.txt for topic Investment Performance Review with count as 8]
# Number of conversations completed: 608
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_9_4_positive_14_neutral.txt for topic Investment Performance Review with count as 9]
# Number of conversations completed: 609
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_10_4_positive_12_negative.txt for topic Investment Performance Review with count as 10]
# Number of conversations completed: 610
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_11_4_positive_5_neutral_11_neutral.txt for topic Investment Performance Review with count as 11]
# Number of conversations completed: 611
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_12_4_positive_19_negative_16_negative.txt for topic Investment Performance Review with count as 12]
# Number of conversations completed: 612
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_13_4_positive_10_negative.txt for topic Investment Performance Review with count as 13]
# Number of conversations completed: 613
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_14_4_positive_5_negative.txt for topic Investment Performance Review with count as 14]
# Number of conversations completed: 614
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_15_4_positive_2_neutral_8_negative.txt for topic Investment Performance Review with count as 15]
# Number of conversations completed: 615
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_16_4_positive_8_neutral.txt for topic Investment Performance Review with count as 16]
# Number of conversations completed: 616
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_17_4_positive_12_negative_6_negative.txt for topic Investment Performance Review with count as 17]
# Number of conversations completed: 617
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_18_4_positive_3_negative.txt for topic Investment Performance Review with count as 18]
# Number of conversations completed: 618
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_19_4_positive_1_negative.txt for topic Investment Performance Review with count as 19]
# Number of conversations completed: 619
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_20_4_positive_7_negative.txt for topic Investment Performance Review with count as 20]
# Number of conversations completed: 620
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_21_4_positive_18_negative.txt for topic Investment Performance Review with count as 21]
# Number of conversations completed: 621
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_22_4_positive_16_negative.txt for topic Investment Performance Review with count as 22]
# Number of conversations completed: 622
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_23_4_positive_7_negative.txt for topic Investment Performance Review with count as 23]
# Number of conversations completed: 623
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_24_4_positive_9_neutral.txt for topic Investment Performance Review with count as 24]
# Number of conversations completed: 624
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_25_4_positive_3_negative.txt for topic Investment Performance Review with count as 25]
# Number of conversations completed: 625
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_26_4_positive_15_neutral.txt for topic Investment Performance Review with count as 26]
# Number of conversations completed: 626
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_27_4_positive_10_neutral.txt for topic Investment Performance Review with count as 27]
# Number of conversations completed: 627
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_28_4_positive_3_neutral_14_negative.txt for topic Investment Performance Review with count as 28]
# Number of conversations completed: 628
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_29_4_positive_7_neutral_6_neutral.txt for topic Investment Performance Review with count as 29]
# Number of conversations completed: 629
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_30_4_positive_14_negative.txt for topic Investment Performance Review with count as 30]
# Number of conversations completed: 630
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_31_4_positive_10_neutral_7_neutral.txt for topic Investment Performance Review with count as 31]
# Number of conversations completed: 631
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_32_4_positive_16_neutral_5_negative.txt for topic Investment Performance Review with count as 32]
# Number of conversations completed: 632
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_33_4_positive_7_negative.txt for topic Investment Performance Review with count as 33]
# Number of conversations completed: 633
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_34_4_positive_13_negative_9_neutral.txt for topic Investment Performance Review with count as 34]
# Number of conversations completed: 634
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_35_4_positive_2_neutral_18_negative.txt for topic Investment Performance Review with count as 35]
# Number of conversations completed: 635
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_36_4_positive_12_negative.txt for topic Investment Performance Review with count as 36]
# Number of conversations completed: 636
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_37_4_positive_8_negative_12_neutral.txt for topic Investment Performance Review with count as 37]
# Number of conversations completed: 637
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_38_4_positive_12_neutral.txt for topic Investment Performance Review with count as 38]
# Number of conversations completed: 638
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_39_4_positive_12_negative.txt for topic Investment Performance Review with count as 39]
# Number of conversations completed: 639
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_40_4_positive_3_neutral.txt for topic Investment Performance Review with count as 40]
# Number of conversations completed: 640
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_41_4_positive_5_neutral.txt for topic Investment Performance Review with count as 41]
# Number of conversations completed: 641
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_42_4_positive_9_negative_2_neutral.txt for topic Investment Performance Review with count as 42]
# Number of conversations completed: 642
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_43_4_positive_1_neutral_11_neutral.txt for topic Investment Performance Review with count as 43]
# Number of conversations completed: 643
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_44_4_positive_9_negative.txt for topic Investment Performance Review with count as 44]
# Number of conversations completed: 644
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_45_4_positive_12_negative_19_neutral.txt for topic Investment Performance Review with count as 45]
# Number of conversations completed: 645
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_46_4_positive_15_negative_0_neutral.txt for topic Investment Performance Review with count as 46]
# Number of conversations completed: 646
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_47_4_positive_1_negative.txt for topic Investment Performance Review with count as 47]
# Number of conversations completed: 647
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_48_4_positive_19_negative_17_neutral.txt for topic Investment Performance Review with count as 48]
# Number of conversations completed: 648
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_49_4_positive_6_neutral.txt for topic Investment Performance Review with count as 49]
# Number of conversations completed: 649
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_50_4_positive_1_neutral.txt for topic Investment Performance Review with count as 50]
# Number of conversations completed: 650
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_51_4_positive_7_negative_9_negative.txt for topic Investment Performance Review with count as 51]
# Number of conversations completed: 651
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_52_4_positive_8_negative.txt for topic Investment Performance Review with count as 52]
# Number of conversations completed: 652
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_53_4_positive_10_negative.txt for topic Investment Performance Review with count as 53]
# Number of conversations completed: 653
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_54_4_positive_14_neutral.txt for topic Investment Performance Review with count as 54]
# Number of conversations completed: 654
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_55_4_positive_11_negative.txt for topic Investment Performance Review with count as 55]
# Number of conversations completed: 655
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_56_4_positive_11_negative.txt for topic Investment Performance Review with count as 56]
# Number of conversations completed: 656
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_57_4_positive_5_negative_0_neutral.txt for topic Investment Performance Review with count as 57]
# Number of conversations completed: 657
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_58_4_positive_0_negative_10_negative.txt for topic Investment Performance Review with count as 58]
# Number of conversations completed: 658
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_59_4_positive_3_neutral.txt for topic Investment Performance Review with count as 59]
# Number of conversations completed: 659
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_60_4_negative_1_neutral.txt for topic Investment Performance Review with count as 60]
# Number of conversations completed: 660
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_61_4_negative_6_positive.txt for topic Investment Performance Review with count as 61]
# Number of conversations completed: 661
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_62_4_negative_17_neutral.txt for topic Investment Performance Review with count as 62]
# Number of conversations completed: 662
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_63_4_negative_2_neutral_9_neutral.txt for topic Investment Performance Review with count as 63]
# Number of conversations completed: 663
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_64_4_negative_8_positive_19_positive.txt for topic Investment Performance Review with count as 64]
# Number of conversations completed: 664
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_65_4_negative_17_neutral.txt for topic Investment Performance Review with count as 65]
# Number of conversations completed: 665
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_66_4_negative_6_positive_19_neutral.txt for topic Investment Performance Review with count as 66]
# Number of conversations completed: 666
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_67_4_negative_15_positive.txt for topic Investment Performance Review with count as 67]
# Number of conversations completed: 667
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_68_4_negative_0_neutral_7_neutral.txt for topic Investment Performance Review with count as 68]
# Number of conversations completed: 668
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_69_4_negative_7_positive_19_neutral.txt for topic Investment Performance Review with count as 69]
# Number of conversations completed: 669
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_70_4_negative_7_positive_0_positive.txt for topic Investment Performance Review with count as 70]
# Number of conversations completed: 670
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_71_4_negative_11_positive_1_positive.txt for topic Investment Performance Review with count as 71]
# Number of conversations completed: 671
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_72_4_negative_3_neutral_11_positive.txt for topic Investment Performance Review with count as 72]
# Number of conversations completed: 672
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_73_4_negative_15_positive_1_neutral.txt for topic Investment Performance Review with count as 73]
# Number of conversations completed: 673
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_74_4_negative_11_neutral_13_neutral.txt for topic Investment Performance Review with count as 74]
# Number of conversations completed: 674
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_75_4_negative_8_positive.txt for topic Investment Performance Review with count as 75]
# Number of conversations completed: 675
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_76_4_negative_12_neutral.txt for topic Investment Performance Review with count as 76]
# Number of conversations completed: 676
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_77_4_negative_8_neutral_10_neutral.txt for topic Investment Performance Review with count as 77]
# Number of conversations completed: 677
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_78_4_negative_17_positive_12_positive.txt for topic Investment Performance Review with count as 78]
# Number of conversations completed: 678
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_79_4_negative_15_neutral_0_positive.txt for topic Investment Performance Review with count as 79]
# Number of conversations completed: 679
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_80_4_negative_1_positive.txt for topic Investment Performance Review with count as 80]
# Number of conversations completed: 680
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_81_4_negative_19_positive.txt for topic Investment Performance Review with count as 81]
# Number of conversations completed: 681
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_82_4_negative_5_positive_1_positive.txt for topic Investment Performance Review with count as 82]
# Number of conversations completed: 682
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_83_4_negative_12_positive_17_neutral.txt for topic Investment Performance Review with count as 83]
# Number of conversations completed: 683
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_84_4_negative_11_positive_6_neutral.txt for topic Investment Performance Review with count as 84]
# Number of conversations completed: 684
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_85_4_negative_0_positive.txt for topic Investment Performance Review with count as 85]
# Number of conversations completed: 685
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_86_4_negative_11_positive_8_neutral.txt for topic Investment Performance Review with count as 86]
# Number of conversations completed: 686
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_87_4_negative_15_positive.txt for topic Investment Performance Review with count as 87]
# Number of conversations completed: 687
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_88_4_negative_6_positive.txt for topic Investment Performance Review with count as 88]
# Number of conversations completed: 688
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_89_4_negative_10_positive_8_positive.txt for topic Investment Performance Review with count as 89]
# Number of conversations completed: 689
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_90_4_negative_16_neutral.txt for topic Investment Performance Review with count as 90]
# Number of conversations completed: 690
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_91_4_negative_16_neutral_10_positive.txt for topic Investment Performance Review with count as 91]
# Number of conversations completed: 691
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_92_4_negative_6_neutral.txt for topic Investment Performance Review with count as 92]
# Number of conversations completed: 692
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_93_4_negative_19_neutral.txt for topic Investment Performance Review with count as 93]
# Number of conversations completed: 693
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_94_4_negative_18_neutral.txt for topic Investment Performance Review with count as 94]
# Number of conversations completed: 694
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_95_4_negative_11_neutral_19_positive.txt for topic Investment Performance Review with count as 95]
# Number of conversations completed: 695
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_96_4_negative_12_positive.txt for topic Investment Performance Review with count as 96]
# Number of conversations completed: 696
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_97_4_negative_10_positive_0_positive.txt for topic Investment Performance Review with count as 97]
# Number of conversations completed: 697
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_98_4_negative_14_positive_17_neutral.txt for topic Investment Performance Review with count as 98]
# Number of conversations completed: 698
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_99_4_negative_9_positive_5_neutral.txt for topic Investment Performance Review with count as 99]
# Number of conversations completed: 699
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_100_4_negative_6_positive.txt for topic Investment Performance Review with count as 100]
# Number of conversations completed: 700
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_101_4_negative_7_neutral.txt for topic Investment Performance Review with count as 101]
# Number of conversations completed: 701
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_102_4_negative_14_positive_11_neutral.txt for topic Investment Performance Review with count as 102]
# Number of conversations completed: 702
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_103_4_negative_6_neutral_3_positive.txt for topic Investment Performance Review with count as 103]
# Number of conversations completed: 703
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_104_4_negative_14_positive_5_neutral.txt for topic Investment Performance Review with count as 104]
# Number of conversations completed: 704
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_105_4_negative_1_positive.txt for topic Investment Performance Review with count as 105]
# Number of conversations completed: 705
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_106_4_negative_10_positive.txt for topic Investment Performance Review with count as 106]
# Number of conversations completed: 706
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_107_4_negative_5_positive_16_neutral.txt for topic Investment Performance Review with count as 107]
# Number of conversations completed: 707
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_108_4_negative_5_positive.txt for topic Investment Performance Review with count as 108]
# Number of conversations completed: 708
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_109_4_negative_6_neutral_13_neutral.txt for topic Investment Performance Review with count as 109]
# Number of conversations completed: 709
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_110_4_negative_8_positive.txt for topic Investment Performance Review with count as 110]
# Number of conversations completed: 710
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_111_4_negative_5_neutral.txt for topic Investment Performance Review with count as 111]
# Number of conversations completed: 711
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_112_4_negative_1_positive_3_neutral.txt for topic Investment Performance Review with count as 112]
# Number of conversations completed: 712
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_113_4_negative_18_neutral_16_neutral.txt for topic Investment Performance Review with count as 113]
# Number of conversations completed: 713
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/4/conversation_114_4_negative_2_neutral_1_neutral.txt for topic Investment Performance Review with count as 114]
# Number of conversations completed: 714
# ...
# Number of conversations completed: 2931
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_82_19_negative_1_neutral_0_neutral.txt for topic Scenario and Sensitivity Analysis with count as 82]
# Number of conversations completed: 2932
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_83_19_negative_3_neutral_15_neutral.txt for topic Scenario and Sensitivity Analysis with count as 83]
# Number of conversations completed: 2933
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_84_19_negative_9_neutral_15_positive.txt for topic Scenario and Sensitivity Analysis with count as 84]
# Number of conversations completed: 2934
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_85_19_negative_8_positive.txt for topic Scenario and Sensitivity Analysis with count as 85]
# Number of conversations completed: 2935
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_86_19_negative_11_positive.txt for topic Scenario and Sensitivity Analysis with count as 86]
# Number of conversations completed: 2936
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_87_19_negative_0_neutral_13_neutral.txt for topic Scenario and Sensitivity Analysis with count as 87]
# Number of conversations completed: 2937
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_88_19_negative_12_positive_14_positive.txt for topic Scenario and Sensitivity Analysis with count as 88]
# Number of conversations completed: 2938
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_89_19_negative_9_positive_0_positive.txt for topic Scenario and Sensitivity Analysis with count as 89]
# Number of conversations completed: 2939
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_90_19_negative_5_positive_12_neutral.txt for topic Scenario and Sensitivity Analysis with count as 90]
# Number of conversations completed: 2940
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_91_19_negative_6_positive.txt for topic Scenario and Sensitivity Analysis with count as 91]
# Number of conversations completed: 2941
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_92_19_negative_13_positive.txt for topic Scenario and Sensitivity Analysis with count as 92]
# Number of conversations completed: 2942
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_93_19_negative_7_positive_2_positive.txt for topic Scenario and Sensitivity Analysis with count as 93]
# Number of conversations completed: 2943
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_94_19_negative_3_positive.txt for topic Scenario and Sensitivity Analysis with count as 94]
# Number of conversations completed: 2944
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_95_19_negative_12_neutral.txt for topic Scenario and Sensitivity Analysis with count as 95]
# Number of conversations completed: 2945
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_96_19_negative_7_neutral_11_positive.txt for topic Scenario and Sensitivity Analysis with count as 96]
# Number of conversations completed: 2946
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_97_19_negative_10_positive_9_positive.txt for topic Scenario and Sensitivity Analysis with count as 97]
# Number of conversations completed: 2947
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_98_19_negative_17_positive_2_neutral.txt for topic Scenario and Sensitivity Analysis with count as 98]
# Number of conversations completed: 2948
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_99_19_negative_11_neutral_16_positive.txt for topic Scenario and Sensitivity Analysis with count as 99]
# Number of conversations completed: 2949
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_100_19_negative_7_neutral.txt for topic Scenario and Sensitivity Analysis with count as 100]
# Number of conversations completed: 2950
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_101_19_negative_17_positive_9_positive.txt for topic Scenario and Sensitivity Analysis with count as 101]
# Number of conversations completed: 2951
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_102_19_negative_9_neutral_13_positive.txt for topic Scenario and Sensitivity Analysis with count as 102]
# Number of conversations completed: 2952
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_103_19_negative_13_positive_8_neutral.txt for topic Scenario and Sensitivity Analysis with count as 103]
# Number of conversations completed: 2953
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_104_19_negative_16_positive.txt for topic Scenario and Sensitivity Analysis with count as 104]
# Number of conversations completed: 2954
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_105_19_negative_2_positive_11_neutral.txt for topic Scenario and Sensitivity Analysis with count as 105]
# Number of conversations completed: 2955
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_106_19_negative_12_neutral_0_neutral.txt for topic Scenario and Sensitivity Analysis with count as 106]
# Number of conversations completed: 2956
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_107_19_negative_17_neutral.txt for topic Scenario and Sensitivity Analysis with count as 107]
# Number of conversations completed: 2957
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_108_19_negative_1_positive_10_neutral.txt for topic Scenario and Sensitivity Analysis with count as 108]
# Number of conversations completed: 2958
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_109_19_negative_14_positive_1_positive.txt for topic Scenario and Sensitivity Analysis with count as 109]
# Number of conversations completed: 2959
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_110_19_negative_15_positive.txt for topic Scenario and Sensitivity Analysis with count as 110]
# Number of conversations completed: 2960
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_111_19_negative_7_neutral_6_positive.txt for topic Scenario and Sensitivity Analysis with count as 111]
# Number of conversations completed: 2961
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_112_19_negative_15_positive.txt for topic Scenario and Sensitivity Analysis with count as 112]
# Number of conversations completed: 2962
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_113_19_negative_4_neutral_3_positive.txt for topic Scenario and Sensitivity Analysis with count as 113]
# Number of conversations completed: 2963
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_114_19_negative_14_neutral_17_positive.txt for topic Scenario and Sensitivity Analysis with count as 114]
# Number of conversations completed: 2964
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_115_19_negative_4_positive_10_positive.txt for topic Scenario and Sensitivity Analysis with count as 115]
# Number of conversations completed: 2965
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_116_19_negative_9_positive.txt for topic Scenario and Sensitivity Analysis with count as 116]
# Number of conversations completed: 2966
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_117_19_negative_15_neutral_18_neutral.txt for topic Scenario and Sensitivity Analysis with count as 117]
# Number of conversations completed: 2967
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_118_19_negative_12_neutral.txt for topic Scenario and Sensitivity Analysis with count as 118]
# Number of conversations completed: 2968
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_119_19_negative_14_neutral.txt for topic Scenario and Sensitivity Analysis with count as 119]
# Number of conversations completed: 2969
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_120_19_neutral_6_negative_5_negative.txt for topic Scenario and Sensitivity Analysis with count as 120]
# Number of conversations completed: 2970
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_121_19_neutral_11_positive.txt for topic Scenario and Sensitivity Analysis with count as 121]
# Number of conversations completed: 2971
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_122_19_neutral_6_negative_11_positive.txt for topic Scenario and Sensitivity Analysis with count as 122]
# Number of conversations completed: 2972
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_123_19_neutral_15_positive_2_negative.txt for topic Scenario and Sensitivity Analysis with count as 123]
# Number of conversations completed: 2973
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_124_19_neutral_14_positive_3_negative.txt for topic Scenario and Sensitivity Analysis with count as 124]
# Number of conversations completed: 2974
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_125_19_neutral_6_positive_11_positive.txt for topic Scenario and Sensitivity Analysis with count as 125]
# Number of conversations completed: 2975
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_126_19_neutral_13_positive_17_negative.txt for topic Scenario and Sensitivity Analysis with count as 126]
# Number of conversations completed: 2976
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_127_19_neutral_9_negative_10_negative.txt for topic Scenario and Sensitivity Analysis with count as 127]
# Number of conversations completed: 2977
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_128_19_neutral_0_positive_8_positive.txt for topic Scenario and Sensitivity Analysis with count as 128]
# Number of conversations completed: 2978
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_129_19_neutral_11_positive_18_negative.txt for topic Scenario and Sensitivity Analysis with count as 129]
# Number of conversations completed: 2979
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_130_19_neutral_13_negative.txt for topic Scenario and Sensitivity Analysis with count as 130]
# Number of conversations completed: 2980
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_131_19_neutral_4_positive_3_negative.txt for topic Scenario and Sensitivity Analysis with count as 131]
# Number of conversations completed: 2981
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_132_19_neutral_17_negative.txt for topic Scenario and Sensitivity Analysis with count as 132]
# Number of conversations completed: 2982
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_133_19_neutral_8_positive_11_positive.txt for topic Scenario and Sensitivity Analysis with count as 133]
# Number of conversations completed: 2983
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_134_19_neutral_6_positive_7_positive.txt for topic Scenario and Sensitivity Analysis with count as 134]
# Number of conversations completed: 2984
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_135_19_neutral_7_positive.txt for topic Scenario and Sensitivity Analysis with count as 135]
# Number of conversations completed: 2985
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_136_19_neutral_6_negative.txt for topic Scenario and Sensitivity Analysis with count as 136]
# Number of conversations completed: 2986
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_137_19_neutral_5_negative_14_negative.txt for topic Scenario and Sensitivity Analysis with count as 137]
# Number of conversations completed: 2987
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_138_19_neutral_7_positive_6_negative.txt for topic Scenario and Sensitivity Analysis with count as 138]
# Number of conversations completed: 2988
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_139_19_neutral_8_positive_9_negative.txt for topic Scenario and Sensitivity Analysis with count as 139]
# Number of conversations completed: 2989
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_140_19_neutral_15_negative.txt for topic Scenario and Sensitivity Analysis with count as 140]
# Number of conversations completed: 2990
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_141_19_neutral_7_positive_10_negative.txt for topic Scenario and Sensitivity Analysis with count as 141]
# Number of conversations completed: 2991
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_142_19_neutral_5_positive.txt for topic Scenario and Sensitivity Analysis with count as 142]
# Number of conversations completed: 2992
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_143_19_neutral_10_negative.txt for topic Scenario and Sensitivity Analysis with count as 143]
# Number of conversations completed: 2993
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_144_19_neutral_16_positive_8_negative.txt for topic Scenario and Sensitivity Analysis with count as 144]
# Number of conversations completed: 2994
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_145_19_neutral_3_positive.txt for topic Scenario and Sensitivity Analysis with count as 145]
# Number of conversations completed: 2995
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_146_19_neutral_16_negative.txt for topic Scenario and Sensitivity Analysis with count as 146]
# Number of conversations completed: 2996
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_147_19_neutral_8_negative.txt for topic Scenario and Sensitivity Analysis with count as 147]
# Number of conversations completed: 2997
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_148_19_neutral_6_positive_5_negative.txt for topic Scenario and Sensitivity Analysis with count as 148]
# Number of conversations completed: 2998
# Saved to /content/drive/MyDrive/Sentiment_Analysis/Finance/Conversation_Data/19/conversation_149_19_neutral_10_negative_0_negative.txt for topic Scenario and Sensitivity Analysis with count as 149]
# Number of conversations completed: 2999
